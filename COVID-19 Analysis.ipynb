# %% [markdown]
#  # COVID-19 Analysis ,visualization & Prediction

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Reading Data
data=pd.read_csv('/Users/anas/Downloads/novel-corona-virus-2019-dataset-2/covid_19_data.csv' ,parse_dates=['Last Update'])
data.rename(columns={'ObservationDate':'Date', 'Country/Region':'Country'}, inplace=True)

#Earliest Cases
data.head()
# Out:
#    SNo        Date Province/State         Country         Last Update  \
# 0    1  01/22/2020          Anhui  Mainland China 2020-01-22 17:00:00
# 1    2  01/22/2020        Beijing  Mainland China 2020-01-22 17:00:00
# 2    3  01/22/2020      Chongqing  Mainland China 2020-01-22 17:00:00
# 3    4  01/22/2020         Fujian  Mainland China 2020-01-22 17:00:00
# 4    5  01/22/2020          Gansu  Mainland China 2020-01-22 17:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
data.shape
# Out:
# (9117, 8)

# %%
#Missing Values
data.isnull().sum().to_frame('null')
# Out:
#                 null
# SNo                0
# Date               0
# Province/State  4088
# Country            0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0

# %% [markdown]
# # Total Confirmed , Deaths and Recovered cases in the world 23/03/2020

# %%
df = data.groupby(["Date", "Country"])[['Date', 'Country', 'Confirmed', 'Deaths', 'Recovered']].sum().reset_index()
sorted_By_Confirmed=df.sort_values('Confirmed',ascending=False)
sorted_By_Confirmed=sorted_By_Confirmed.drop_duplicates('Country')

world_Confirmed_Total=sorted_By_Confirmed['Confirmed'].sum()
world_Deaths_Total=sorted_By_Confirmed['Deaths'].sum()
world_Recovered_Total=sorted_By_Confirmed['Recovered'].sum()

Active=world_Confirmed_Total-world_Deaths_Total-world_Recovered_Total

world_Deaths_rate=(world_Deaths_Total*100)/world_Confirmed_Total
world_Recovered_rate=(world_Recovered_Total*100)/world_Confirmed_Total

US=sorted_By_Confirmed[sorted_By_Confirmed['Country']=='US']
US_Recovered_rate=(int(US['Recovered'].values)*100)/int(US['Confirmed'].values)

China=sorted_By_Confirmed[sorted_By_Confirmed['Country']=='Mainland China']
China_Recovered_rate=(int(China['Recovered'].values)*100)/int(China['Confirmed'].values)


veri={'Total Confirmed cases  in the world':world_Confirmed_Total,'Total Deaths cases in the world':world_Deaths_Total,'Total Recovered cases in the world':world_Recovered_Total,'Total Active Cases':Active,'Rate of Recovered Cases %':world_Recovered_rate,'Rate of Deaths Cases %':world_Deaths_rate,'Rate of Recovered China cases %':China_Recovered_rate, 'Rate of Recovered US Cases%':US_Recovered_rate}
veri=pd.DataFrame.from_dict(veri, orient='index' ,columns=['Total'])

veri.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_af0b807c_700f_11ea_a60d_d0817acf9560row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row1_col0 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row2_col0 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row3_col0 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row5_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row6_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_af0b807c_700f_11ea_a60d_d0817acf9560row7_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_af0b807c_700f_11ea_a60d_d0817acf9560" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row0" class="row_heading level0 row0" >Total Confirmed cases  in the world</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row0_col0" class="data row0 col0" >530581</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row1" class="row_heading level0 row1" >Total Deaths cases in the world</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row1_col0" class="data row1 col0" >23982</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row2" class="row_heading level0 row2" >Total Recovered cases in the world</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row2_col0" class="data row2 col0" >122721</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row3" class="row_heading level0 row3" >Total Active Cases</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row3_col0" class="data row3 col0" >383878</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row4" class="row_heading level0 row4" >Rate of Recovered Cases %</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row4_col0" class="data row4 col0" >23.1296</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row5" class="row_heading level0 row5" >Rate of Deaths Cases %</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row5_col0" class="data row5 col0" >4.51995</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row6" class="row_heading level0 row6" >Rate of Recovered China cases %</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row6_col0" class="data row6 col0" >91.0982</td>
#             </tr>
#             <tr>
#                         <th id="T_af0b807c_700f_11ea_a60d_d0817acf9560level0_row7" class="row_heading level0 row7" >Rate of Recovered US Cases%</th>
#                         <td id="T_af0b807c_700f_11ea_a60d_d0817acf9560row7_col0" class="data row7 col0" >0.8123</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Graphic that illustrates Increasing infections cases per day

# %%
cases_per_Day = data.groupby(["Date"])['Confirmed','Deaths', 'Recovered'].sum().reset_index()
sorted_By_Confirmed1=cases_per_Day.sort_values('Date',ascending=False)

x=cases_per_Day.index

y=cases_per_Day.Confirmed
y1=cases_per_Day.Deaths
y2=cases_per_Day.Recovered

sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(12,10 ))

plt.scatter(x,y,color='yellow' , label='Confirmed Cases')
plt.scatter(x,y1,color='red' ,label="Deaths Cases")
plt.scatter(x,y2,color='green',label="Recovered Cases")
plt.title("Increasing infections cases in the world per day .")
ax.legend(ncol=2, loc='upper left', frameon=True)
plt.show()

# %% [markdown]
# ## Table that illustrates Increasing infections cases in the world per day .

# %%
sorted_By_Confirmed1.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_35f1863e_700d_11ea_a60d_d0817acf9560row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row1_col1 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row1_col2 {
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row1_col3 {
#             background-color:  #880811;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row2_col1 {
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row2_col2 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row2_col3 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row3_col1 {
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row3_col2 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row3_col3 {
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row4_col1 {
#             background-color:  #ec382b;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row4_col2 {
#             background-color:  #f0402f;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row4_col3 {
#             background-color:  #bd151a;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row5_col1 {
#             background-color:  #f44d38;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row5_col2 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row5_col3 {
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row6_col1 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row6_col2 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row6_col3 {
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row7_col1 {
#             background-color:  #fb7757;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row7_col2 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row7_col3 {
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row8_col1 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row8_col2 {
#             background-color:  #fc9576;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row8_col3 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row9_col1 {
#             background-color:  #fc9373;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row9_col2 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row9_col3 {
#             background-color:  #e43027;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row10_col1 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row10_col2 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row10_col3 {
#             background-color:  #eb372a;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row11_col1 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row11_col2 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row11_col3 {
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row12_col1 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row12_col2 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row12_col3 {
#             background-color:  #f24633;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row13_col1 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row13_col2 {
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row13_col3 {
#             background-color:  #f44d38;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row14_col1 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row14_col2 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row14_col3 {
#             background-color:  #f5533b;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row15_col1 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row15_col2 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row15_col3 {
#             background-color:  #f6583e;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row16_col1 {
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row16_col2 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row16_col3 {
#             background-color:  #f96044;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row17_col1 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row17_col2 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row17_col3 {
#             background-color:  #fa6648;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row18_col1 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row18_col2 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row18_col3 {
#             background-color:  #fb6b4b;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row19_col1 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row19_col2 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_35f1863e_700d_11ea_a60d_d0817acf9560row19_col3 {
#             background-color:  #fb7151;

# %% [markdown]
# # Coron Virus With Numbers
#
# Confirmed --              Cumulative number of confirmed cases till that date <br>
# Deaths --               Cumulative number of of deaths till that date <br>
# Recovered --              Cumulative number of recovered cases till that date <br>
# Active -- Active Cases<br>
# Recovered Cases Rate % -- rate of Recovered Cases from total of Confirmed cases in same Country <br>
# Deaths Cases Rate % --    rate of death Cases from total of Confirmed cases in same Country <br>
# Total Cases Rate % --     rate of total cases from Total cases in the world <br>

# %%
Recovered_rate=(sorted_By_Confirmed['Recovered']*100)/sorted_By_Confirmed['Confirmed']
Deaths_rate=(sorted_By_Confirmed['Deaths']*100)/sorted_By_Confirmed['Confirmed']
cases_rate=(sorted_By_Confirmed.Confirmed*100)/world_Confirmed_Total

sorted_By_Confirmed['Active']=sorted_By_Confirmed['Confirmed']-sorted_By_Confirmed['Deaths']-sorted_By_Confirmed['Recovered']
sorted_By_Confirmed['Recovered Cases Rate %']=pd.DataFrame(Recovered_rate)
sorted_By_Confirmed['Deaths Cases Rate %']=pd.DataFrame(Deaths_rate)
sorted_By_Confirmed['Total Cases Rate %']=pd.DataFrame(cases_rate)


print("Sorted By Confirmed Cases , Scroll table down ")
sorted_By_Confirmed.style.background_gradient(cmap='Reds')
# Out:
# Sorted By Confirmed Cases , Scroll table down
# <style  type="text/css" >
#     #T_364217de_700d_11ea_a60d_d0817acf9560row0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col3 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col6 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col7 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row0_col8 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col2 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col3 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col5 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col6 {
#             background-color:  #920a13;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col7 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row1_col8 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col2 {
#             background-color:  #79040f;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col4 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col5 {
#             background-color:  #c9181d;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col6 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col7 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row2_col8 {
#             background-color:  #79040f;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col2 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col3 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col4 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col5 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col6 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col7 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row3_col8 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col2 {
#             background-color:  #f96044;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col3 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col4 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col5 {
#             background-color:  #fb7656;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col6 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col7 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row4_col8 {
#             background-color:  #f96044;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col2 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col3 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col4 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col5 {
#             background-color:  #fcb296;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col6 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col7 {
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row5_col8 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col2 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col3 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col4 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col5 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col6 {
#             background-color:  #fc9879;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col7 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row6_col8 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col2 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col3 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col5 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col6 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col7 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row7_col8 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row8_col2 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row8_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row8_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_364217de_700d_11ea_a60d_d0817acf9560row8_col5 {
#             background-color:  #fedccd;
#             color:  #000000;

# %%
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15,15 ))

sns.barplot(x="Confirmed", y="Country", data=sorted_By_Confirmed.head(20),
            label="Confirmed", color="b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Recovered", y="Country", data=sorted_By_Confirmed.head(20),
            label="Recovered", color="g")

sns.set_color_codes("muted")
sns.barplot(x="Deaths", y="Country", data=sorted_By_Confirmed.head(20),
            label="Deaths", color="r")

# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True)

# %% [markdown]
# ## What happened in one day ?  (New cases | New Deaths ) - 03/23/2020
# difference between 22/03 and 23/03

# %%
df_Difference = data.groupby(["Date", "Country"])[['Date', 'Country', 'Confirmed','Deaths']].sum().reset_index()
sorted_By_Confirmed_Difference=df_Difference.sort_values('Country',ascending=False)

x1=sorted_By_Confirmed_Difference[sorted_By_Confirmed_Difference.Date=='03/23/2020'].reset_index().drop('index',axis=1)
x2=sorted_By_Confirmed_Difference[sorted_By_Confirmed_Difference.Date=='03/22/2020'].reset_index().drop('index',axis=1)

h=pd.merge(x2,x1,on='Country')
h['New Confirmed Cases']=h['Confirmed_y']-h['Confirmed_x']
h['New Deaths ']=h['Deaths_y']-h['Deaths_x']

h1=h.sort_values('New Confirmed Cases',ascending=False).head(50)
h1=h1.drop(['Confirmed_x','Deaths_x','Date_x','Confirmed_y','Deaths_y'],axis=1).style.background_gradient(cmap='Greens')
print("The New Cases in 23/03")
h1
# Out:
# The New Cases in 23/03
# <style  type="text/css" >
#     #T_36eded84_700d_11ea_a60d_d0817acf9560row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row0_col3 {
#             background-color:  #d1edcb;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row1_col2 {
#             background-color:  #39a257;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row1_col3 {
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row2_col2 {
#             background-color:  #7ac77b;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row2_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row3_col2 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row3_col3 {
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row4_col2 {
#             background-color:  #9bd696;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row4_col3 {
#             background-color:  #b5e1ae;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row5_col2 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row5_col3 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row6_col2 {
#             background-color:  #e4f5df;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row6_col3 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row7_col2 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row7_col3 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row8_col2 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row8_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row9_col2 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row9_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row10_col2 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row10_col3 {
#             background-color:  #eff9ec;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row11_col2 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row11_col3 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row12_col2 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row12_col3 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row13_col2 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row13_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row14_col2 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row14_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row15_col2 {
#             background-color:  #f3faf0;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row15_col3 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row16_col2 {
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row16_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row17_col2 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row17_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row18_col2 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row18_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row19_col2 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row19_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row20_col2 {
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row20_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row21_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row21_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row22_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row22_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row23_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row23_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row24_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row24_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row25_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row25_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row26_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row26_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row27_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row27_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row28_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row28_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row29_col2 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_36eded84_700d_11ea_a60d_d0817acf9560row29_col3 {
#             background-color:  #

# %% [markdown]
# # Top 10  infected Countries

# %%
sorted_By_Confirmed1=sorted_By_Confirmed.head(10)
x=sorted_By_Confirmed1.Country
y=sorted_By_Confirmed1.Confirmed
plt.rcParams['figure.figsize'] = (12, 10)
sns.barplot(x,y,order=x ,palette="rocket").set_title('Total Cases / Deaths / Recovered')  #graf çizdir (Most popular)
# Out:
# Text(0.5, 1.0, 'Total Cases / Deaths / Recovered')

# %% [markdown]
# ### Cases Rate per country of total cases in the world

# %%
Top7=sorted_By_Confirmed.iloc[0:8,-1].values
others=sorted_By_Confirmed.iloc[8:,-1].sum()
x=np.array(Top7)
x2=np.array(others)
rates=np.concatenate((x, x2), axis=None)

rate_perCountry=pd.DataFrame(data=rates,index=[sorted_By_Confirmed['Country'].head(9)] ,columns=['rate'])
rate_perCountry.rename(index={'Switzerland': "other Countries"},inplace=True)


labels=rate_perCountry.index
sizes=rate_perCountry['rate'].values

explode = None  # explode 1st slice
plt.subplots(figsize=(8,8))
plt.pie(sizes, explode=explode, labels=labels,autopct='%1.1f%%', shadow=False, startangle=0)
plt.axis('equal')
print("cases rate per country of total cases in the world ")
plt.show()
# Out:
# cases rate per country of total cases in the world

# %% [markdown]
# # Prediction Future cases

# %%
#Train & Test Data 
x_data=pd.DataFrame(cases_per_Day.index)
y_data=pd.DataFrame(cases_per_Day.Confirmed)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.1,random_state=0)

# %% [markdown]
# # Polynomial Regression to predict future cases .

# %%
#Polynomal Regression (degree=5)
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly_reg=PolynomialFeatures(degree=5)
x_poly=poly_reg.fit_transform(x_train)
lin_reg2=LinearRegression()
lin_reg2.fit(x_poly,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Model Graphic

# %%
cases_per_Day = data.groupby(["Date"])['Confirmed','Deaths', 'Recovered'].sum().reset_index()
sorted_By_Confirmed1=cases_per_Day.sort_values('Date',ascending=False)

x=cases_per_Day.index

y=cases_per_Day.Confirmed

plt.scatter(x,y,color='red')
plt.plot(x_test,lin_reg2.predict(poly_reg.fit_transform(x_test)),color='blue')
plt.title("Polynomial Regression Model ")
plt.show()

# %% [markdown]
# ## Test algorithm

# %%
y_pred=lin_reg2.predict(poly_reg.fit_transform(x_test))

result=pd.DataFrame(y_pred)
result['Real Value']=y_test.iloc[:,:].values
result['Predicted Value']=pd.DataFrame(y_pred)
result=result[['Real Value','Predicted Value']]
result
# Out:
#    Real Value  Predicted Value
# 0    105836.0    101788.881659
# 1     76199.0     76879.021373
# 2     97886.0     96268.737624
# 3    417966.0    421571.355438
# 4     80415.0     85194.310627
# 5     79570.0     83913.532770
# 6     78599.0     80812.958780

# %%
from sklearn.metrics import r2_score

print('Polynomial Regession  R2 Score   : ',r2_score(y_test, y_pred))
# Out:
# Polynomial Regession  R2 Score   :  0.9991675395389554

# %% [markdown]
# # Make Predict For Future Days

# %%
#today is 03/23/2020
print("After {0} day will be {1} case in the world".format((67-len(cases_per_Day)),lin_reg2.predict(poly_reg.fit_transform([[67]]))))
print("After {0} day will be {1} case in the world".format((77-len(cases_per_Day)),lin_reg2.predict(poly_reg.fit_transform([[77]]))))
print("After {0} day will be {1} case in the world".format((87-len(cases_per_Day)),lin_reg2.predict(poly_reg.fit_transform([[87]]))))
print("After {0} day will be {1} case in the world".format((97-len(cases_per_Day)),lin_reg2.predict(poly_reg.fit_transform([[97]]))))
print("After {0} day will be {1} case in the world".format((107-len(cases_per_Day)),lin_reg2.predict(poly_reg.fit_transform([[107]]))))
# Out:
# After 2 day will be [[724507.79259333]] case in the world
# After 12 day will be [[1941778.71527158]] case in the world
# After 22 day will be [[4493804.8562523]] case in the world
# After 32 day will be [[9219473.09095058]] case in the world
# After 42 day will be [[17239490.00257777]] case in the world
